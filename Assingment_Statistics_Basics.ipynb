# %%
#Que 1.Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss nominal, ordinal, interval, and ratio scales.?

#Ans . #Data can be divided into two types: qualitative and quantitative. Qualitative data is descriptive and non-numerical, while quantitative data is numerical
#and can be counted

#Qualitative data

#this type of data is descriptive and non-numerical, and is often used to categorize "yes" or "no" answers in surveys. Examples include eye color, the type of car
#someone drives, or attributes like intelligence, honesty, #and creativity.

#Quantitative data
#This type of data is numerical and can be counted. Examples include distance, speed, height, length, and weight.

#There are also four types of scales for measuring data: nominal, ordinal, interval, and ratio:
#Nominal - This type of data is categorical and has no natural order. For example, gender or eye color are nominal data.

#Ordinal -This type of data is categorical and has a natural order, but the intervals between categories may not be equal. For example, education level or Likert
#scale responses are ordinal data.

#nterval-This type of data is numerical and has a specific order, with equal and measurable intervals between points. For example, temperature in Celsius or
#Fahrenheit is interval data.

#Ratio-This type of data is numerical and has a natural zero point, indicating the absence of the attribute being measured. For example, height or weight are
#ratio data.

# %%
#Que 2. 2. What are the measures of central tendency, and when should you use each? Discuss the mean, median,and mode with examples and situations where each is
#appropriate ?

#Ans.  #n statistics, the central tendency is the descriptive summary of a data set. Through the single value from the dataset, it reflects the centre of the data
 #distribution. Moreover, it does not #provide information regarding individual data from the dataset, where it gives a summary of the dataset. Generally, the central tendency of a dataset can be defined using some of the #measures in statistics.

#Measures of Central Tendency
#The central tendency of the dataset can be found out using the three important measures namely mean, median and mode.

#The mean represents the average value of the dataset. It can be calculated as the sum of all the values in the dataset divided by the number of values.
#In general, it is considered as the #arithmetic mean. Some other measures of mean used to find the central tendency are as follows:

#Geometric Mean
#Harmonic Mean
#Weighted Mean
#It is observed that if all the values in the dataset are the same, then all geometric, arithmetic and harmonic mean values are the same. If there is variability
##in the data, then the mean value #differs. Calculating the mean value is completely easy. The formula to calculate the mean value is given by:

import seaborn as sns

sns.load_dataset('tips')

a= sns.load_dataset('tips')
a
a.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
z =a.head()
z
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd
import numpy as np

# %%
z['total_bill']
# Out:
# 0    16.99
# 1    10.34
# 2    21.01
# 3    23.68
# 4    24.59
# Name: total_bill, dtype: float64

# %%
z['total_bill'].mean()
# Out:
# 19.322000000000003

# %%
#Median
#Median is the middle value of the dataset in which the dataset is arranged in the ascending order or in descending order. When the dataset contains an even
#number of values, then the #median value of the dataset can be found by taking the mean of the middle two values.

#Consider the given dataset with the odd number of observations arranged in descending order – 23, 21, 18, 16, 15, 13, 12, 10, 9, 7, 6, 5, and 2

#Here 12 is the middle or median number that has 6 values above it and 6 values below it.

##Now, consider another example with an even number of observations that are arranged in descending order – 40, 38, 35, 33, 32, 30, 29, 27, 26, 24, 23, 22, 19,
#and 17

#When you look at the given dataset, the two middle values obtained are 27 and 29.
#Now, find out the mean value for these two numbers.
#i.e.,(27+29)/2 =28
#Therefore, the median for the given data distribution is 28.

#Mode
#The mode represents the frequently occurring value in the dataset. Sometimes the dataset may contain multiple modes and in some cases, it does not contain any mode at all.

#Consider the given dataset 5, 4, 2, 3, 2, 1, 5, 4, 5

# %%
#Que 3.Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?

#Ans. #Dispersion is a statistical measure of how spread out a set of data is, or how much it varies around a central value. Variance and standard deviation are
#two common ways to measure #dispersion:
#Variance
#A measure of how spread out all data points are in a set. It's calculated by finding the mean squared difference between each data point and the mean.
#Standard deviation
#The square root of the variance. It's calculated by taking the square root of a value derived from comparing data points to the mean.
#Dispersion is often used in conjunction with measures of central tendency, which describe the center of a data set. A small dispersion value means that the
#data is clustered around the #mean, and the mean is a good representative of the data. A large dispersion value means that the data is spread out, and the mean
#is not a good representative of the data.

# %%
#Que 4. What is a box plot, and what can it tell you about the distribution of data?

#Ans. # The idea of box plot was presented by John Tukey in 1970. He wrote about it in his book “Exploratory Data Analysis” in 1977. Box plot is also known as a
#whisker plot, box-and-whisker plot, #or simply a box-and whisker diagram. Box plot is a graphical representation of the distribution of a dataset.
#It displays key summary statistics such as the median, quartiles, and potential #outliers in a concise and visual manner. By using Box plot you can provide a
#summary of the distribution, identify potential and compare different datasets in a compact and visual manner.

box = [100, 110, 110, 110, 120, 120, 130, 140, 140, 150, 170, 220]
sns.boxplot(box)
# Out:
# <Axes: >

# %%
#Que 5.Discuss the role of random sampling in making inferences about populations.?

#Ans. Random sampling, also known as probability sampling, is a method for selecting a sample from a population that allows researchers to make inferences about the population as a whole. Random sampling is important because it allows researchers to make generalizations about a population without surveying every individual in that population.
#Here are some ways that random sampling helps researchers make inferences about populations:
#Reduces bias
#Random sampling removes bias from the research process by ensuring that every item in the population has an equal chance of being selected.
#High internal validity
#Randomization helps reduce the impact of confounding variables, which can lead to high internal validity.
#High external validity
#With a large enough sample size, a simple random sample can represent the characteristics of the larger population, which leads to high external validity.
#Reliable and valid results
#Random sampling can lead to highly reliable and valid results for making inferences about the population.

# %%
#que 6. Explain the concept of skewness and its types. How does skewness affect the interpretation of data?

#Ans. #Skewness is a measure of how asymmetric a data distribution is, and it can affect the interpretation of data in several ways:
#Data normality
#Skewness can indicate if a variable is normally distributed, which is an assumption for many statistical procedures. A normal distribution has zero skew and is
 #a bell curve with a perfect #symmetrical shape.
#Data analysis
#Skewness can affect which analyses can be done and the outcomes of those analyses. Outliers and skewness can make data not normal, which can prevent or affect
# a statistical analysis.
#Distribution shape
#Skewness can help you understand the shape of data, which is important for data science. The shape of data helps you understand where the most information lies
 #and analyze outliers.
#Here are the types of skewness:
#Positive skew
#The tail is on the right side of the distribution, and the values are more concentrated towards the right side. The mean, median, and mode are all positive.
#Negative skew
#The tail is on the left side of the distribution, and the data points are more concentrated towards the left side. The mean, median, and mode are all negative.

# %%
#Que 7 What is the interquartile range (IQR), and how is it used to detect outliers?

#Ans 7. Outliers

#The outliers may suggest experimental errors, variability in a measurement, or an anomaly. The age of a person may wrongly be recorded as 200 rather than 20
#Years. Such an outlier should definitely be discarded from the dataset. However, not all outliers are bad. Some outliers signify that data is significantly
#different from others. For example, it may indicate an anomaly like bank fraud or a rare disease.

#Significance of outliers:
#1.Outliers badly affect the mean and standard deviation of the dataset. These may statistically give erroneous results.
#2.Most machine learning algorithms do not work well in the presence of outliers. So it is desirable to detect and remove outliers.
#3.Outliers are highly useful in anomaly detection like fraud detection where the fraud transactions are very different from normal transactions.

# Load the diamonds dataset
diamonds = sns.load_dataset('diamonds')

# Calculate the quartiles for the 'price' column
Q1 = diamonds['price'].quantile(0.25)
Q3 = diamonds['price'].quantile(0.75)

# Calculate the interquartile range (IQR)
IQR = Q3 - Q1

# Identify outliers:
# Values below Q1 - 1.5 * IQR or above Q3 + 1.5 * IQR are considered outliers.
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = diamonds[(diamonds['price'] < lower_bound) | (diamonds['price'] > upper_bound)]

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
print("Number of outliers:", len(outliers))
print("Outliers:\n", outliers)
# Out:
# Q1: 950.0
# Q3: 5324.25
# IQR: 4374.25
# Lower Bound: -5611.375
# Upper Bound: 11885.625
# Number of outliers: 3540
# Outliers:
#         carat        cut color clarity  depth  table  price     x     y     z
# 23820   1.17      Ideal     F    VVS1   62.1   57.0  11886  6.82  6.73  4.21
# 23821   2.08      Ideal     I     SI2   62.0   56.0  11886  8.21  8.10  5.06
# 23822   1.70    Premium     I     VS2   62.2   58.0  11888  7.65  7.60  4.74
# 23823   1.09      Ideal     F      IF   61.6   55.0  11888  6.59  6.65  4.08
# 23824   1.68      Ideal     E     SI2   60.4   55.0  11888  7.79  7.70  4.68
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27745   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00  5.01
# 27746   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# ...

# %%
#Que 8.Discuss the conditions under which the binomial distribution is used ?

#Ans. The binomial distribution is used to model probabilities when specific conditions are met, including:
#Fixed probability of success: The probability of success is the same for each trial
#Two mutually exclusive outcomes: There are only two possible outcomes, success or failure


#Criteria of Binomial Distribution

#1. Fixed trials
#The process under investigation must have a fixed number of trials that cannot be altered in the course of the analysis. During the analysis, each trial must be
#performed in a uniform manner, although each trial may yield a different outcome.

#In the binomial probability formula, the number of trials is represented by the letter “n.” An example of a fixed trial may be coin flips, free throws, wheel
#spins, etc. The number of times that each trial is conducted is known from the start. If a coin is flipped 10 times, each flip of the coin is a trial.

#2. Independent trials
#The other condition of a binomial probability is that the trials are independent of each other. In simple terms, the outcome of one trial should not affect the
#outcome of the subsequent trials.

#When using certain sampling methods, there is a possibility of having trials that are not completely independent of each other, and binomial distribution may
#only be used when the size of the population is large vis-a-vis the sample size.

#An example of independent trials may be tossing a coin or rolling a dice. When tossing a coin, the first event is independent of the subsequent events.

#3. Fixed probability of success
#In a binomial distribution, the probability of getting a success must remain the same for the trials we are investigating. For example, when tossing a coin, the
# probability of flipping a coin is ½ or 0.5 for every trial we conduct, since there are only two possible outcomes.

#In some sampling techniques, such as sampling without replacement, the probability of success from each trial may vary from one trial to the other. For example,
#assume that there are 50 boys in a population of 1,000 students. The probability of picking a boy from that population is 0.05.

#In the next trial, there will be 49 boys out of 999 students. The probability of picking a boy in the next trial is 0.049. It shows that in subsequent trials,
#the probability from one trial to the next will vary slightly from the prior trial.

#4. Two mutually exclusive outcomes
#In binomial probability, there are only two mutually exclusive outcomes, i.e., success or failure. While success is generally a positive term, it can be used to
 #mean that the outcome of the trial agrees with what you have defined as a success, whether it is a positive or negative outcome.

#For example, when a business receives a consignment of lamps with a lot of breakages, the business can define success for the trial to be every lamp that has
#broken glass. A failure can be defined as when the lamps have zero broken glasses.

#In our example, the instances of broken lamps may be used to denote success as a way of showing that a high proportion of the lamps in the consignment is broken.
 #and that there is a low probability of getting a consignment of lamps with zero breakages.

#Example of Binomial Distribution
#Suppose, according to the latest police reports, 80% of all petty crimes are unresolved, and in your town, at least three of such petty crimes are committed. The three crimes are all independent of each other. From the given data, what is the probability that one of the three crimes will be resolved?

#Solution
#The first step in finding the binomial probability is to verify that the situation satisfies the four rules of binomial distribution:

#Number of fixed trials (n): 3 (Number of petty crimes)
#Number of mutually exclusive outcomes: 2 (solved and unsolved)
#The probability of success (p): 0.2 (20% of cases are solved)
#Independent trials: Yes

# %%
#Que 9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).?

#Ans. The empirical rule, also known as the 68-95-99.7 rule, is a guideline for how data is distributed in a normal distribution:
#68%: of data points fall within one standard deviation of the mean
#95%: of data points fall within two standard deviations of the mean
#99.7%: of data points fall within three standard deviations of the mean
#The empirical rule is a shorthand way to remember the percentage of values that lie within a given interval in a normal distribution. Analysts use the empirical
#rule to see how much data falls within a specified interval away from the data set's mean. For example, investment analysts can use it to estimate the
#volatility of a particular investment.

# %%
#Que 10 Provide a real-life example of a Poisson process and calculate the probability for a specific event.?

#Ans.Here's a real-life example of a Poisson process and how to calculate the probability of a specific event:
#Example
#A council is considering whether to place a recovery vehicle on a road that experiences an average of 5 incidents during morning rush hour. The council will only place the vehicle if the probability of more than 5 incidents in a morning is less than 30%.

#Calculation To calculate the probability of more than 5 incidents, use the formula \(P(X>5)=1-P(X\le 5)\)

#The Poisson distribution is a model that can be used to describe events that occur independently and at a constant rate. It can be used in many real-world situations, including

#Estimating customer numbers
#Restaurants can use the Poisson distribution to estimate how many customers they can expect on a given day.

#Calculating call center staffing
#Call centers can use the Poisson distribution to calculate how many employees they need to hire.

#Modeling phone calls
#The Poisson distribution can model the number of phone calls an office receives during a given time period

#Predicting overflow floods
#The Poisson distribution can be used to predict the probability of overflow floods on a river.

#Modeling soccer goals
#The Poisson distribution can be used to predict the probability of a certain number of goals in a soccer match#                                                      absolute;bottom:-4px;right:-4px;border-radius:50%;line-height:0;padding:2px;background-color:var(--xhUGwc)}.y6CIle .NffHwb{background-color:var(--XKMDxc)}.YXe3R .NffHwb{background-color:var(--XKMDxc)}.hor8Kd{position:relative;border-radius:50%;overflow:hidden}.cFB3ze{height:28px;width:28px;line-height:28px}.tBMkq{height:20px;width:20px;line-height:20px}.yidq7b{height:12px;width:12px;background-color:#fff}.UcKXnb .bJVp8c{color:#5e5e5e}.d0FfLc{height:10px;width:10px;background-color:var(--TSWZIb)}.m46kvb{margin-left:0;margin-top:3px}.PCBdKc.PCBdKc{font-size:11px;line-height:13px;letter-spacing:0;color:var(--bbQxAb)}.vDF3Oc.vDF3Oc .KegKec{color:#9e9e9e}.KegKec{color:var(--bbQxAb)}.xuPcX{font-size:12px;line-height:16px;letter-spacing:0.1px;color:var(--IXoxUe);order:2;white-space:nowrap}.xuPcX.al4kQ{max-height:calc(var(--google-fs,1)*16px)}       The Poisson distribution is a model that can be used to describe events that occur independently and at a constant rate. It can be used in many real-world situations, including:  Poisson Distribution | Brilliant Math & Science WikiFor example, the Poisson distribution is appropriate for modeling the number of phone calls an office would receive during the noo...BrilliantREAL LIFE EXAMPLE OF POISSON DISTRIBUTION - LinkedInRestaurants employ Poisson distribution to roughly estimate the number of customers that are expected to visit the res...Sandhya V  ·  LinkedIn  ·  1y   Estimating customer numbers Restaurants can use the Poisson distribution to estimate how many customers they can expect on a given day.  REAL LIFE EXAMPLE OF POISSON DISTRIBUTION - LinkedInRestaurants employ Poisson distribution to roughly estimate the number of customers that are expected to visit the res...Sandhya V  ·  LinkedIn  ·  1yCalculating call center staffing Call centers can use the Poisson distribution to calculate how many employees they need to hire.  REAL LIFE EXAMPLE OF POISSON DISTRIBUTION - LinkedInRestaurants employ Poisson distribution to roughly estimate the number of customers that are expected to visit the res...Sandhya V  ·  LinkedIn  ·  1yModeling phone calls The Poisson distribution can model the number of phone calls an office receives during a given time period.  Poisson Distribution | Brilliant Math & Science WikiFor example, the Poisson distribution is appropriate for modeling the number of phone calls an office would receive during the noo...BrilliantPredicting overflow floods The Poisson distribution can be used to predict the probability of overflow floods on a river.  Poisson distribution - WikipediaExamples of probability for Poisson distributions On a particular river, overflow floods occur once every 100 years on average. Ca...WikipediaModeling soccer goals The Poisson distribution can be used to predict the probability of a certain number of goals in a soccer match.

# %%
#Que 11. Explain what a random variable is and differentiate between discrete and continuous random variables.

#Ans. #A random variable is a fundamental concept in probability theory and statistics. The main difference between discrete and continuous random variables is the range of values they can take on:
#Discrete random variables
#Have a countable number of distinct values. For example, the outcome of rolling a die is a discrete random variable because it can only land on one of six possible numbers.
#Continuous random variables
#Can take on any value in a given interval. For example, the mass of an animal would be a continuous random variable because it could theoretically be any non-negative number.
#Here are some other differences between discrete and continuous random variables:
#Range
#The range of a discrete distribution is countable, while the range of a continuous variable is not.
#Use
#Discrete random variables are used for counting, and continuous random variables are used for measuring.
#Mathematical operations
#Summation is used to find a range of probabilities for discrete random variables and integration is used for continuous random variables.

# %%
#Que 12. Provide an example dataset, calculate both covariance and correlation, and interpret the results.

#Ans.

import seaborn as sns
import pandas as pd

# Load the diamonds dataset
diamonds = sns.load_dataset('diamonds')

# Select relevant columns for analysis (e.g., carat and price)
df = diamonds[['carat', 'price']]

# Calculate the covariance matrix
covariance_matrix = df.cov()
print("Covariance Matrix:\n", covariance_matrix)

# Calculate the correlation matrix
correlation_matrix = df.corr()
print("\nCorrelation Matrix:\n", correlation_matrix)


# Interpretation:

# Covariance:
# - A positive covariance between carat and price indicates that as carat increases,
#   price tends to increase as well.
# - The magnitude of the covariance represents the strength of the linear relationship.
# - However, the scale of covariance depends on the units of the variables, making it
#   difficult to compare across different datasets.


# Correlation:
# - Correlation is a standardized measure of the linear relationship between variables.
# - It ranges from -1 to +1.
# - A correlation of +1 indicates a perfect positive linear relationship, -1 a perfect
#   negative linear relationship, and 0 no linear relationship.
# - The correlation between carat and price tells us the strength and direction of the
#   linear relationship between these two variables. A high positive correlation
#   suggests a strong tendency for diamond price to increase with increasing carat
#   weight.


# Example interpretation:

# If we observe a positive covariance and a positive correlation between carat and
# price, it means that as the carat weight of a diamond increases, its price tends
# to increase as well. The strength of the relationship can be assessed by the
# magnitude of the correlation coefficient (closer to +1 indicates a stronger
# relationship).
# Out:
# Covariance Matrix:
#               carat         price
# carat     0.224687  1.742765e+03
# price  1742.765364  1.591563e+07
#
# Correlation Matrix:
#            carat     price
# carat  1.000000  0.921591
# price  0.921591  1.000000
